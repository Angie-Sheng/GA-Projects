# %%
import time
import random
time.sleep(random.random()*3)

# %%
import re
import pandas as pd
from scrapy.selector import Selector
from scrapy.http import HtmlResponse
import requests
from bs4 import BeautifulSoup
import json

# %%
salary_ranges = ['0-70000','70000-120000','120000-999999']
# declare an empty list for storing urls
job_urls = {}

for salary_range in salary_ranges:
    job_urls[salary_range]=[]
    for page in range(1,20):
        # iteraterate through the 10 pages of jobs
        r = requests.get("https://www.seek.com.au/Data-Engineer-jobs?page={0}&salaryrange={1}&salarytype=annual".format(str(page),salary_range))

        # turn into a BeautifulSoup object
        soup = BeautifulSoup(r.text, 'lxml')

        # find urls on page
        urls = soup.find_all(attrs={'data-automation':"jobTitle"})
        
        if urls != []: 
            job_urls[salary_range].extend(urls)

# %% [markdown]
# If there is one job which belongs to two or more salary ranges, the concatenated list will be a mess. Thus, I create different dataframes for different salary ranges and then combine them as one.

# %%
df_1 = pd.DataFrame()
df_1['Link'] = job_urls['0-70000']
df_1['Salary Range'] = '0-70000'

# %%
df_2 = pd.DataFrame()
df_2['Link'] = job_urls['70000-120000']
df_2['Salary Range'] = '70000-120000'

# %%
df_3 = pd.DataFrame()
df_3['Link'] = job_urls['120000-999999']
df_3['Salary Range'] = '120000-999999'

# %%
url_pd = df_1.append(df_2).append(df_3)

# %%
url_pd['Link_1'] =['https://www.seek.com.au' + re.search('(\/job\/[0-9]{8})',i.attrs['href']).group(0) for i in url_pd['Link']]

# %%
url_pd['Title'] = [i.text for i in url_pd['Link']]

# %%
url_pd = url_pd.drop('Link',axis='columns')

# %%
columns = ['Salary Range', 'Link', "Title"]
url_pd.columns=columns

# %% [markdown]
# We can obtain a DataFrame which contains the urls for BI jobs for different salary ranges.

# %%
url_pd.head(10)
# Out:
#   Salary Range                                  Link  \
# 0      0-70000  https://www.seek.com.au/job/39690163
# 1      0-70000  https://www.seek.com.au/job/39749280
# 2      0-70000  https://www.seek.com.au/job/39663464
# 3      0-70000  https://www.seek.com.au/job/39661130
# 4      0-70000  https://www.seek.com.au/job/39688588
# 5      0-70000  https://www.seek.com.au/job/39663050
# 6      0-70000  https://www.seek.com.au/job/39638588
# 7      0-70000  https://www.seek.com.au/job/39551948
# 8      0-70000  https://www.seek.com.au/job/39581505
# 9      0-70000  https://www.seek.com.au/job/39754088
#
#                               Title
# 0              Junior Data Engineer
# 1  Data Engineer - 6 Month Contract
# 2              Junior Data Engineer
# 3          Agile Data Engineer (x2)
# 4                 Big Data Engineer
# 5                     Data Engineer
# 6                 Big Data Engineer
# 7                     Data Engineer
# 8                 Big Data Engineer
# 9              Data Centre Engineer

# %%
#for stemming
import re

def replace(string, substitutions):

    substrings = sorted(substitutions, key=len, reverse=True)
    regex = re.compile('|'.join(map(re.escape, substrings)))
    return regex.sub(lambda match: substitutions[match.group(0)], string)

# %% [markdown]
# Start scrapying details for each url.

# %%
job_listing_date=[]
job_expiry_date=[]
job_title = []
job_teaser=[]
job_advertiser=[]
job_area=[]
job_worktype=[]
job_classification=[]
job_salary=[]
job_salary_type=[]
job_description_details=[]
job_description_strong = []
job_location =[]

for index, job in enumerate(url_pd['Link']):
    # iterate through all the urls
    r = requests.get(job)
    
    # turn into a BeautifulSoup object
    soup = BeautifulSoup(r.text, 'lxml')
    
    # find job descriptions
    jd_data = soup.find_all(attrs={'data-automation':'server-state'})[0]
    jd_raw= jd_data.text[3:].split('\n  ')[1][25:][:-1]
    jd_dict = json.loads(jd_raw)
    jd_dashboard = jd_dict['jobdetails']['result']
    
    if jd_dashboard['listingDate']:
        job_listing_date.append(jd_dashboard['listingDate'])
    else:
        job_listing_date.append('N/A')
        
    if jd_dashboard['expiryDate']:
        job_expiry_date.append(jd_dashboard['expiryDate'])
    else:
        job_expiry_date.append('N/A')
        
    if jd_dashboard['title']:
        job_title.append(jd_dashboard['title'])
    else:
        job_title.append('N/A')
        
    if jd_dashboard['teaser']:
        job_teaser.append(jd_dashboard['teaser'])
    else:
        job_teaser.append('N/A')
        
    if jd_dashboard['advertiser']['description']:
        job_advertiser.append(jd_dashboard['advertiser']['description'])
    else:
        job_advertiser.append('N/A')
        
    if jd_dashboard['locationHierarchy']['area']:
        job_area.append(jd_dashboard['locationHierarchy']['area'])
    else:
        job_area.append('N/A')
        
    if jd_dashboard['workType']:
        job_worktype.append(jd_dashboard['workType'])
    else:
        job_worktype.append('N/A')
        
    if jd_dashboard['classification']['description']:
        job_classification.append(jd_dashboard['classification']['description'])
    else:
        job_classification.append('N/A')
        
    if jd_dashboard['salary']:
        job_salary.append(jd_dashboard['salary'])
    else:
        job_salary.append('N/A')
        
    if jd_dashboard['salaryType']:
        job_salary_type.append(jd_dashboard['salaryType'])
    else:
        job_salary_type.append('N/A')
        
    if jd_dashboard['locationHierarchy']['city']:
        job_location.append(jd_dashboard['locationHierarchy']['city'])
    else:
        job_location.append('N/A')
    
    jd_detail = soup.find(attrs={'data-automation':'mobileTemplate'})
    job_description_details.append(jd_detail)

# %%
url_pd['Listing Date'] = job_listing_date
url_pd['Expiry Date'] =job_expiry_date
url_pd['Job Title']=job_title
url_pd['Job Teaser']=job_teaser
url_pd['Advertiser'] = job_advertiser
url_pd['Area'] = job_area
url_pd['Work Type'] = job_worktype
url_pd['Classification'] = job_classification
url_pd['Salary'] = job_salary
url_pd['Salary Type'] = job_salary_type
url_pd['JD'] = job_description_details
url_pd['Location'] =job_location

# %% [markdown]
# Check the type for 'JD' column and start cleaning.

# %%
type(job_description_details)
# Out:
# list

# %%
job_description_clean=[]
job_description_strong = []
for i in range(0,len(url_pd['JD'])):
    try:
        strong_word = job_description_details[i].find_all('strong')
        strong_word_list = [u.get_text(strip=True) for u in strong_word if strong_word != False]
        job_description_strong.append(strong_word_list)

        string = job_description_details[i].get_text()
        repla = {u'\xa0':'  ',u'\xe2\x80\x9d':'  ', u'\n':'  '}
        job_description_clean.append(replace(string,repla))
    except:
        job_description_strong.append('N/A')
        job_description_clean.append('N/A')

# %%
url_pd['Job Description'] = job_description_clean
url_pd['Strong Words'] = job_description_strong

# %%
data_engineer_jobs = url_pd.copy()

# %%
data_engineer_jobs.to_csv('data_engineer_scraping.csv')

# %%
data_engineer_jobs.tail(10)
# Out:
#       Salary Range                                  Link  \
# 370  120000-999999  https://www.seek.com.au/job/39745017
# 371  120000-999999  https://www.seek.com.au/job/39676957
# 372  120000-999999  https://www.seek.com.au/job/39575722
# 373  120000-999999  https://www.seek.com.au/job/39598892
# 374  120000-999999  https://www.seek.com.au/job/39656857
# 375  120000-999999  https://www.seek.com.au/job/39587578
# 376  120000-999999  https://www.seek.com.au/job/39763542
# 377  120000-999999  https://www.seek.com.au/job/39574660
# 378  120000-999999  https://www.seek.com.au/job/39761345
# 379  120000-999999  https://www.seek.com.au/job/39723365
#
#                                                  Title  \
# 370  Quality Automation Tester (API Testing - Rest/...
# 371                                      Product Owner
# 372                                  Python Developers
# 373                                     SCADA Engineer
# 374                           MINE PRODUCTION ENGINEER
# 375  IBM MDM Engineer - Multiple Multi Year Contrac...
# 376                              Senior Civil Designer
# 377                  Senior Technical Business Analyst
# 378                                       Data Analyst
# 379                           Control Systems Engineer
#
#                  Listing Date               Expiry Date  \
# 370  2019-08-20T04:00:23.000Z  2019-09-19T13:59:59.000Z
# 371  2019-08-11T14:40:10.000Z  2019-09-11T13:59:59.000Z
# 372  2019-07-29T04:05:46.000Z  2019-08-28T04:05:46.000Z
# 373  2019-07-31T07:31:31.000Z  2019-08-30T13:59:59.000Z
# 374  2019-08-08T00:51:33.000Z  2019-09-07T00:51:33.000Z
# 375  2019-07-30T06:01:21.000Z  2019-08-29T13:59:59.000Z
# 376  2019-08-22T02:29:18.000Z  2019-09-21T02:29:17.000Z
# 377  2019-07-29T02:54:12.000Z  2019-08-28T13:59:59.000Z
# 378  2019-08-22T00:04:11.000Z  2019-09-21T13:59:59.000Z
# 379  2019-08-16T05:40:08.000Z  2019-09-15T05:40:07.000Z
#
#                                              Job Title  \
# 370  Quality Automation Tester (API Testing - Rest/...
# 371                                      Product Owner
# 372                                  Python Developers
# 373                                     SCADA Engineer
# 374                           MINE PRODUCTION ENGINEER
# 375  IBM MDM Engineer - Multiple Multi Year Contrac...
# 376                              Senior Civil Designer
# 377                  Senior Technical Business Analyst
# 378                                       Data Analyst
# 379                           Control Systems Engineer
#
#                                             Job Teaser  \
# 370  Permanent Role -  Quality Eye for The Team Wor...
# 371  A data driven Product Owner to work on a large...
# 372  We have multiple positions for Python Develope...
# 373  SCADA analyst/engineer bridge real-time tech p...
# 374  We are looking for a pro-active Production Eng...
# 375  IBM MDM Advanced Edition - Largest Project in ...
# 376  Senior Civil Designer required to help a growi...
# 377  A leading Australian Banking Institution curre...
# 378  Seeking a passionate Data Analyst who loves wo...
# 379  Market leading, global provider of intelligent...
#
#                       Advertiser                               Area  \
# 370                Revolution IT                                N/A
# 371       Woolworth Liquor Group  CBD, Inner West & Eastern Suburbs
# 372            Zone IT Solutions  CBD, Inner West & Eastern Suburbs
# 373      Paul Ingle & Associates                CBD & Inner Suburbs
# 374        Sandfire Resources NL                                N/A
# 375  TRS - Accounting  & Finance                CBD & Inner Suburbs
# 376  Technical Resources Pty Ltd       CBD, Inner & Western Suburbs
# 377            Huxley Associates                                N/A
# 378                 GFG Alliance  CBD, Inner West & Eastern Suburbs
# 379  Kapsch TrafficCom Australia  CBD, Inner West & Eastern Suburbs
#
#          Work Type                          Classification  \
# 370      Full Time  Information & Communication Technology
# 371      Full Time  Information & Communication Technology
# 372      Full Time  Information & Communication Technology
# 373  Contract/Temp  Information & Communication Technology
# 374      Full Time              Mining, Resources & Energy
# 375  Contract/Temp  Information & Communication Technology
# 376  Contract/Temp                             Engineering
# 377  Contract/Temp            Banking & Financial Services
# 378      Full Time  Information & Communication Technology
# 379      Full Time                             Engineering
#
#                                     Salary    Salary Type  \
# 370                                    N/A  AnnualPackage
# 371                                    N/A  AnnualPackage
# 372                    $100,000 - $149,999  AnnualPackage
# 373                                    N/A     HourlyRate
# 374                                    N/A  AnnualPackage
# 375                       $700 > $1000 p/d     HourlyRate
# 376  Permanent staff or contract available     HourlyRate
# 377                            competitive     HourlyRate
# 378                                    N/A  AnnualPackage
# 379                                    N/A  AnnualPackage
#
#                                                     JD  \
# 370  [[ , [ , <div><strong>About the Company:</stro...
# 371  [[ ], [ ],  , [[About Us]],  , [The Endeavour ...
# 372  [[We are hiring multiple Python Developers for...
# 373  [[SCADA Analyst/Engineer to establish and main...
# 374  [[[<strong>Who we are</strong>]],  , [[Sandfir...
# 375  [Our client is looking to hire experienced , [...
# 376  [[[About the Business and Role]],  , [Senior C...
# 377  [[A leading Australian Banking Institution cur...
# 378  [[GFG Alliance],  has an agile, entrepreneuria...
# 379  [[[About us]],  , [Kapsch TrafficCom is a mark...
#
#                           Location  \
# 370                         Sydney
# 371                         Sydney
# 372                         Sydney
# 373                      Melbourne
# 374  Geraldton, Gascoyne & Midwest
# 375                      Melbourne
# 376                          Perth
# 377                         Sydney
# 378                         Sydney
# 379                         Sydney
#
#                                        Job Description  \
# 370    About the Company:Revolution IT is a leading...
# 371      About Us The Endeavour Drinks Group ambiti...
# 372  We are hiring multiple Python Developers for S...
# 373  SCADA Analyst/Engineer to establish and mainta...
# 374  Who we are Sandfire is a leading Australian co...
# 375  Our client is looking to hire experienced  IBM...
# 376  About the Business and Role Senior Civil Desig...
# 377  A leading Australian Banking Institution curre...
# 378  GFG Alliance has an agile, entrepreneurial cul...
# 379  About us Kapsch TrafficCom is a market leading...
#
#                                           Strong Words
# 370  [About the Company:, About the Role:, , Requir...
# 371  [About Us, Product Owner - Endeavour X, Furthe...
# 372  [Required Skills and experience:, About Zone I...
# 373                [Expertise and Skills Requirements]
# 374  [Who we are, Our People, The Role:, Production...
# 375  [IBM MDM Engineer, Contract and Permanent Appl...
# 376  [About the Business and Role, Responsibilities...
# 377  [The candidate MUST have Financial Services ex...
# 378  [GFG Alliance, About our team, About the role,...
# 379                    [About us, The role, About you]
